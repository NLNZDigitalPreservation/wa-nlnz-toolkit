# %% [markdown]
# # Exploring Access Methods for NLNZ Web archive dataset
#
# This notebook includes the following sections,
# 1. Use Memento and outbackCDX to query data.
# 2. Parsing WARC files.
# 3. Extracting metadata (URLs, timestamps, MIME types).
# 4. Visualizing simple stats (volume by year, domain types).

# %% [markdown]
# ## Install required python packages

# %%
# !pip -q install warcio playwright validators
# !pip -q install -i https://test.pypi.org/simple/ wa-nlnz-toolkit

# %% [markdown]
# ## Query web archive data using Memento
#
# The **Memento protocol** makes it easier to find and use archived versions of web pages, even if other APIs aren't available. This gives us machine-readable information about web captures.
#
# In the following section, we'll see how NLNZ web archive support the Memento protocol. Specifically, we'll look at three main features:
# - TimeGate - get the version of a page closest to a date you choose.
# - TimeMap -  see all archived versions of a page.
# - Memento - change how an archived page is shown using special URL options

# %%
import datetime
import pandas as pd
import wa_nlnz_toolkit as want

# %%
webpage = "www.natlib.govt.nz"

# default query - get latest capture
dict(want.query_memento(webpage).headers)
# Out:
# {'Date': 'Tue, 09 Sep 2025 23:38:58 GMT',
#  'Server': 'Apache/2.4.6 (Red Hat Enterprise Linux) OpenSSL/1.0.2k-fips mod_fcgid/2.3.9',
#  'Content-Type': 'text/html; charset=UTF-8',
#  'Link': '<http://www.natlib.govt.nz/>; rel="original", <https://ndhadeliver.natlib.govt.nz/webarchive/http://www.natlib.govt.nz/>; rel="timegate", <https://ndhadeliver.natlib.govt.nz/webarchive/timemap/link/http://www.natlib.govt.nz/>; rel="timemap"; type="application/link-format", <https://ndhadeliver.natlib.govt.nz/webarchive/20250908102349mp_/http://www.natlib.govt.nz/>; rel="memento"; datetime="Mon, 08 Sep 2025 10:23:49 GMT"',
#  'Vary': 'accept-datetime',
#  'Expect-CT': 'max-age=86400, enforce',
#  'X-XSS-Protection': '1; mode=block',
#  'X-Content-Type-Options': 'nosniff',
#  'X-Permitted-Cross-Domain-Policies': 'none',
#  'Strict-Transport-Security': 'max-age=31536000; includeSubDomains',
#  'Referrer-Policy': 'no-referrer',
#  'Keep-Alive': 'timeout=5, max=100',
#  'Connection': 'Keep-Alive',
#  'Set-Cookie': 'visid_incap_227072=sXgkc1UITsSNPAhKgAAInpK6wGgAAAAAQUIPAAAAAAADXQlVvwtj3KSUj9k7c9Se; expires=Wed, 09 Sep 2026 15:21:33 GMT; HttpOnly; path=/; Domain=.natlib.govt.nz, incap_ses_997_227072=1UhpQhsiolC+tNxdWA7WDZK6wGgAAAAAy8xWjerxucIevHtHoDIYUg==; path=/; Domain=.natlib.govt.nz',
#  'X-CDN': 'Imperva',
#  'Transfer-Encoding': 'chunked',
#  'X-Iinfo': '10-21623181-21623182 NNNN CT(19 19 0) RT(1757461138209 63) q(0 0 0 0) r(1 1) U5'}

# %%
# or get a tidy-up version
want.get_memento_urls(webpage)
# Out:
# {'original': 'http://www.natlib.govt.nz/',
#  'timegate': 'https://ndhadeliver.natlib.govt.nz/webarchive/http://www.natlib.govt.nz/',
#  'timemap': 'https://ndhadeliver.natlib.govt.nz/webarchive/timemap/link/http://www.natlib.govt.nz/',
#  'memento': 'https://ndhadeliver.natlib.govt.nz/webarchive/20250908102349mp_/http://www.natlib.govt.nz/'}

# %% [markdown]
# The *link* field contains the Memento information. For this case, we can see it contains 4 link types as follows:
#
# - **original**: the url that was archived (e.g., https://covid19.govt.nz/)
# - **timegate**: the harvested url (e.g., https://ndhadeliver.natlib.govt.nz/webarchive/https://covid19.govt.nz/)
# - **timemap**: list of all available captures over time (e.g., https://ndhadeliver.natlib.govt.nz/webarchive/timemap/link/https://covid19.govt.nz/)
# - **memento**: the url of the specific archived version of the webpage (e.g., https://ndhadeliver.natlib.govt.nz/webarchive/20250728214105mp_/https://covid19.govt.nz/)
#
# By default, the *memento* shows the url from the latest capture. If a specific datetime was provided, it will return the capture closest in time to the given datetime. Example is shown below.

# %%
# query for a capture closest to a given datetime
dt_required = datetime.datetime(2020, 1, 1, 0, 0, 0)
dict(want.query_memento(webpage, dt=dt_required).headers)
# Out:
# {'Date': 'Tue, 09 Sep 2025 23:39:00 GMT',
#  'Server': 'Apache/2.4.6 (Red Hat Enterprise Linux) OpenSSL/1.0.2k-fips mod_fcgid/2.3.9',
#  'Content-Type': 'text/html; charset=UTF-8',
#  'Link': '<http://www.natlib.govt.nz/>; rel="original", <https://ndhadeliver.natlib.govt.nz/webarchive/http://www.natlib.govt.nz/>; rel="timegate", <https://ndhadeliver.natlib.govt.nz/webarchive/timemap/link/http://www.natlib.govt.nz/>; rel="timemap"; type="application/link-format", <https://ndhadeliver.natlib.govt.nz/webarchive/20200130060111mp_/http://www.natlib.govt.nz/>; rel="memento"; datetime="Thu, 30 Jan 2020 06:01:11 GMT"',
#  'Vary': 'accept-datetime',
#  'Expect-CT': 'max-age=86400, enforce',
#  'X-XSS-Protection': '1; mode=block',
#  'X-Content-Type-Options': 'nosniff',
#  'X-Permitted-Cross-Domain-Policies': 'none',
#  'Strict-Transport-Security': 'max-age=31536000; includeSubDomains',
#  'Referrer-Policy': 'no-referrer',
#  'Keep-Alive': 'timeout=5, max=98',
#  'Connection': 'Keep-Alive',
#  'Set-Cookie': 'visid_incap_227072=P6QC4a2ARtSdMGnyC3hnfJO6wGgAAAAAQUIPAAAAAABaQ3kaVL9y/dNufP52ktax; expires=Wed, 09 Sep 2026 15:21:33 GMT; HttpOnly; path=/; Domain=.natlib.govt.nz, incap_ses_997_227072=A88qHU9UsXJZt9xdWA7WDZS6wGgAAAAAk9KtO9t8grfqJ7/AozC7eA==; path=/; Domain=.natlib.govt.nz',
#  'X-CDN': 'Imperva',
#  'Transfer-Encoding': 'chunked',
#  'X-Iinfo': '10-21623181-21623182 SNNN RT(1757461138209 2029) q(0 1 1 0) r(1 1) U5'}

# %%
# or get the tidy-up version
want.get_memento_urls(webpage, dt=dt_required)
# Out:
# {'original': 'http://www.natlib.govt.nz/',
#  'timegate': 'https://ndhadeliver.natlib.govt.nz/webarchive/http://www.natlib.govt.nz/',
#  'timemap': 'https://ndhadeliver.natlib.govt.nz/webarchive/timemap/link/http://www.natlib.govt.nz/',
#  'memento': 'https://ndhadeliver.natlib.govt.nz/webarchive/20200130060111mp_/http://www.natlib.govt.nz/'}

# %% [markdown]
# ### Get full list of captures from _timemap_
#
# Memento Timemap provide a list of webpage captures for a given webpage. It is available from Pywb (NLNZ selective web archive) and OpenWayback systems. For Pywb, hree formats are supported - link, cdxj, and json.
#
# The example below show a timemap for the given webpage from NLNZ selective web archive.

# %%
want.get_timemap(webpage)
# Out:
# https://ndhadeliver.natlib.govt.nz/webarchive/timemap/json/www.natlib.govt.nz
#                                urlkey                         url       mime  \
# timestamp
# 2004-07-11 21:32:25  nz,govt,natlib)/  http://www.natlib.govt.nz/  text/html
# 2006-07-04 03:31:35  nz,govt,natlib)/  http://www.natlib.govt.nz/  text/html
# 2007-03-22 04:15:46  nz,govt,natlib)/  http://www.natlib.govt.nz/  text/html
# 2008-02-25 06:02:38  nz,govt,natlib)/  http://www.natlib.govt.nz/  text/html
# 2008-10-19 22:53:43  nz,govt,natlib)/  http://www.natlib.govt.nz/  text/html
# ...                               ...                         ...        ...
# 2025-08-04 19:03:40  nz,govt,natlib)/     https://natlib.govt.nz/  text/html
# 2025-09-04 12:11:18  nz,govt,natlib)/      http://natlib.govt.nz/  text/html
# 2025-09-04 12:11:24  nz,govt,natlib)/     https://natlib.govt.nz/  text/html
# 2025-09-08 10:23:46  nz,govt,natlib)/      http://natlib.govt.nz/  text/html
# 2025-09-08 10:23:49  nz,govt,natlib)/     https://natlib.govt.nz/  text/html
#
#                     status                            digest redirect  \
# timestamp
# 2004-07-11 21:32:25    200  JV66FPIIX6IJTB42TNHMQDEU5Z3LFBCK        -
# 2006-07-04 03:31:35    200  JKXIM5NTOXWFNC5UOIAN37AGPV2KL73O        -
# 2007-03-22 04:15:46    200  CU2KIAIJGUZD4IOV43D7LE2J5TVMUJYR        -
# 2008-02-25 06:02:38    200  2IIVSKCHCNVKN6Z273YKZBEW6QVMYXKK        -
# 2008-10-19 22:53:43    200  6TCIF3SQHDMFZWZ2YTJ5AFNTSYUPYZX7        -
# ...                    ...                               ...      ...
# 2025-08-04 19:03:40    200  OIDDMZRGBYM5BP3V5VIVABZQOKPJILGV        -
# 2025-09-04 12:11:18    301  DFS4JFJMZDAIFJRQP3LHAYNFPKVWMMX2        -
# 2025-09-04 12:11:24    200  B545ERXBLTOCXX6CJZQBC2CF4TWXAJZY        -
# 2025-09-08 10:23:46    301  DFS4JFJMZDAIFJRQP3LHAYNFPKVWMMX2        -
# 2025-09-08 10:23:49    200  U2ABCYWSRP6UV5W2ESVG7YZCJLGJOQJ3        -
#
#                     robotflags length    offset            filename  \
# timestamp
# 2004-07-11 21:32:25          -      0       976    V1-FL1645590.arc
# 2006-07-04 03:31:35          -      0       976    V1-FL1645520.arc
# 2007-03-22 04:15:46          -      0     19799     V1-FL481509.arc
# 2008-02-25 06:02:38          -      0   2717767     V1-FL538322.arc
# 2008-10-19 22:53:43          -      0  48523900     V1-FL617362.arc
# ...                        ...    ...       ...                 ...
# 2025-08-04 19:03:40          -      -  78080125  V1-FL94835963.warc
# 2025-09-04 12:11:18          -      -  26316599  V1-FL94997298.warc
# 2025-09-04 12:11:24          -      -  27802697  V1-FL94997298.warc
# 2025-09-08 10:23:46          -      -  29801086  V1-FL94998111.warc
# 2025-09-08 10:23:49          -      -  29887246  V1-FL94998111.warc
#
#                          source source-coll  \
# timestamp
# 2004-07-11 21:32:25  webarchive  webarchive
# 2006-07-04 03:31:35  webarchive  webarchive
# 2007-03-22 04:15:46  webarchive  webarchive
# 2008-02-25 06:02:38  webarchive  webarchive
# 2008-10-19 22:53:43  webarchive  webarchive
# ...                         ...         ...
# 2025-08-04 19:03:40  webarchive  webarchive
# 2025-09-04 12:11:18  webarchive  webarchive
# 2025-09-04 12:11:24  webarchive  webarchive
# 2025-09-08 10:23:46  webarchive  webarchive
# 2025-09-08 10:23:49  webarchive  webarchive
#
#                                                                                                   access_url
# timestamp
# 2004-07-11 21:32:25  https://ndhadeliver.natlib.govt.nz/webarchive/20040711213225/http://www.natlib.govt.nz/
# 2006-07-04 03:31:35  https://ndhadeliver.natlib.govt.nz/webarchive/20060704033135/http://www.natlib.govt.nz/
# 2007-03-22 04:15:46  https://ndhadeliver.natlib.govt.nz/webarchive/20070322041546/http://www.natlib.govt.nz/
# 2008-02-25 06:02:38  https://ndhadeliver.natlib.govt.nz/webarchive/20080225060238/http://www.natlib.govt.nz/
# 2008-10-19 22:53:43  https://ndhadeliver.natlib.govt.nz/webarchive/20081019225343/http://www.natlib.govt.nz/
# ...                                                                                                      ...
# 2025-08-04 19:03:40     https://ndhadeliver.natlib.govt.nz/webarchive/20250804190340/https://natlib.govt.nz/
# 2025-09-04 12:11:18      https://ndhadeliver.natlib.govt.nz/webarchive/20250904121118/http://natlib.govt.nz/
# 2025-09-04 12:11:24     https://ndhadeliver.natlib.govt.nz/webarchive/20250904121124/https://natlib.govt.nz/
# 2025-09-08 10:23:46      https://ndhadeliver.natlib.govt.nz/webarchive/20250908102346/http://natlib.govt.nz/
# 2025-09-08 10:23:49     https://ndhadeliver.natlib.govt.nz/webarchive/20250908102349/https://natlib.govt.nz/
#
# [1404 rows x 13 columns]

# %% [markdown]
# Note that the load_url field contains the URL used by Pywb internally, which cannot be used directly to access the specific version of web archive.
#
#
# Also, Memento supports changing the way it is presented by adding some modifiers to the url. For example,
#
# - **mp_** modifier: indicate "main page" content replay.
# - **id_** modifier: returns the original harvested version of the webpage.
# - **if_** modifier: returns the view with web archive headers (default for NLNZ web archive).
#
# For more information, check https://pywb.readthedocs.io/en/latest/manual/rewriter.html?highlight=id_#url-rewriting

# %% [markdown]
# ## Query web archive data using CDX API
#
# Because our OutbackCDX server is not accessed internally, the following CDX API queries were actually redirected by the pywb to the outbackCDX server. As a result, some native CDX query params are not supported, such as setting cdx output format.

# %%
df_captures = want.query_cdx_index(webpage)
df_captures
# Out:
#                                urlkey                         url       mime  \
# timestamp
# 2004-07-11 21:32:25  nz,govt,natlib)/  http://www.natlib.govt.nz/  text/html
# 2006-07-04 03:31:35  nz,govt,natlib)/  http://www.natlib.govt.nz/  text/html
# 2007-03-22 04:15:46  nz,govt,natlib)/  http://www.natlib.govt.nz/  text/html
# 2008-02-25 06:02:38  nz,govt,natlib)/  http://www.natlib.govt.nz/  text/html
# 2008-10-19 22:53:43  nz,govt,natlib)/  http://www.natlib.govt.nz/  text/html
# ...                               ...                         ...        ...
# 2025-08-04 19:03:40  nz,govt,natlib)/     https://natlib.govt.nz/  text/html
# 2025-09-04 12:11:18  nz,govt,natlib)/      http://natlib.govt.nz/  text/html
# 2025-09-04 12:11:24  nz,govt,natlib)/     https://natlib.govt.nz/  text/html
# 2025-09-08 10:23:46  nz,govt,natlib)/      http://natlib.govt.nz/  text/html
# 2025-09-08 10:23:49  nz,govt,natlib)/     https://natlib.govt.nz/  text/html
#
#                     status                            digest redirect  \
# timestamp
# 2004-07-11 21:32:25    200  JV66FPIIX6IJTB42TNHMQDEU5Z3LFBCK        -
# 2006-07-04 03:31:35    200  JKXIM5NTOXWFNC5UOIAN37AGPV2KL73O        -
# 2007-03-22 04:15:46    200  CU2KIAIJGUZD4IOV43D7LE2J5TVMUJYR        -
# 2008-02-25 06:02:38    200  2IIVSKCHCNVKN6Z273YKZBEW6QVMYXKK        -
# 2008-10-19 22:53:43    200  6TCIF3SQHDMFZWZ2YTJ5AFNTSYUPYZX7        -
# ...                    ...                               ...      ...
# 2025-08-04 19:03:40    200  OIDDMZRGBYM5BP3V5VIVABZQOKPJILGV        -
# 2025-09-04 12:11:18    301  DFS4JFJMZDAIFJRQP3LHAYNFPKVWMMX2        -
# 2025-09-04 12:11:24    200  B545ERXBLTOCXX6CJZQBC2CF4TWXAJZY        -
# 2025-09-08 10:23:46    301  DFS4JFJMZDAIFJRQP3LHAYNFPKVWMMX2        -
# 2025-09-08 10:23:49    200  U2ABCYWSRP6UV5W2ESVG7YZCJLGJOQJ3        -
#
#                     robotflags length    offset            filename  \
# timestamp
# 2004-07-11 21:32:25          -      0       976    V1-FL1645590.arc
# 2006-07-04 03:31:35          -      0       976    V1-FL1645520.arc
# 2007-03-22 04:15:46          -      0     19799     V1-FL481509.arc
# 2008-02-25 06:02:38          -      0   2717767     V1-FL538322.arc
# 2008-10-19 22:53:43          -      0  48523900     V1-FL617362.arc
# ...                        ...    ...       ...                 ...
# 2025-08-04 19:03:40          -      -  78080125  V1-FL94835963.warc
# 2025-09-04 12:11:18          -      -  26316599  V1-FL94997298.warc
# 2025-09-04 12:11:24          -      -  27802697  V1-FL94997298.warc
# 2025-09-08 10:23:46          -      -  29801086  V1-FL94998111.warc
# 2025-09-08 10:23:49          -      -  29887246  V1-FL94998111.warc
#
#                                                                                                                      load_url  \
# timestamp
# 2004-07-11 21:32:25  https://wlgprdowapp01.natlib.govt.nz/nlnzwebarchive_PROD/ap/20040711213225id_/http://www.natlib.govt.nz/
# 2006-07-04 03:31:35  https://wlgprdowapp01.natlib.govt.nz/nlnzwebarchive_PROD/ap/20060704033135id_/http://www.natlib.govt.nz/
# 2007-03-22 04:15:46  https://wlgprdowapp01.natlib.govt.nz/nlnzwebarchive_PROD/ap/20070322041546id_/http://www.natlib.govt.nz/
# 2008-02-25 06:02:38  https://wlgprdowapp01.natlib.govt.nz/nlnzwebarchive_PROD/ap/20080225060238id_/http://www.natlib.govt.nz/
# 2008-10-19 22:53:43  https://wlgprdowapp01.natlib.govt.nz/nlnzwebarchive_PROD/ap/20081019225343id_/http://www.natlib.govt.nz/
# ...                                                                                                                       ...
# 2025-08-04 19:03:40     https://wlgprdowapp01.natlib.govt.nz/nlnzwebarchive_PROD/ap/20250804190340id_/https://natlib.govt.nz/
# 2025-09-04 12:11:18      https://wlgprdowapp01.natlib.govt.nz/nlnzwebarchive_PROD/ap/20250904121118id_/http://natlib.govt.nz/
# 2025-09-04 12:11:24     https://wlgprdowapp01.natlib.govt.nz/nlnzwebarchive_PROD/ap/20250904121124id_/https://natlib.govt.nz/
# 2025-09-08 10:23:46      https://wlgprdowapp01.natlib.govt.nz/nlnzwebarchive_PROD/ap/20250908102346id_/http://natlib.govt.nz/
# 2025-09-08 10:23:49     https://wlgprdowapp01.natlib.govt.nz/nlnzwebarchive_PROD/ap/20250908102349id_/https://natlib.govt.nz/
#
#                          source source-coll  \
# timestamp
# 2004-07-11 21:32:25  webarchive  webarchive
# 2006-07-04 03:31:35  webarchive  webarchive
# 2007-03-22 04:15:46  webarchive  webarchive
# 2008-02-25 06:02:38  webarchive  webarchive
# 2008-10-19 22:53:43  webarchive  webarchive
# ...                         ...         ...
# 2025-08-04 19:03:40  webarchive  webarchive
# 2025-09-04 12:11:18  webarchive  webarchive
# 2025-09-04 12:11:24  webarchive  webarchive
# 2025-09-08 10:23:46  webarchive  webarchive
# 2025-09-08 10:23:49  webarchive  webarchive
#
#                                                                                                   access_url
# timestamp
# 2004-07-11 21:32:25  https://ndhadeliver.natlib.govt.nz/webarchive/20040711213225/http://www.natlib.govt.nz/
# 2006-07-04 03:31:35  https://ndhadeliver.natlib.govt.nz/webarchive/20060704033135/http://www.natlib.govt.nz/
# 2007-03-22 04:15:46  https://ndhadeliver.natlib.govt.nz/webarchive/20070322041546/http://www.natlib.govt.nz/
# 2008-02-25 06:02:38  https://ndhadeliver.natlib.govt.nz/webarchive/20080225060238/http://www.natlib.govt.nz/
# 2008-10-19 22:53:43  https://ndhadeliver.natlib.govt.nz/webarchive/20081019225343/http://www.natlib.govt.nz/
# ...                                                                                                      ...
# 2025-08-04 19:03:40     https://ndhadeliver.natlib.govt.nz/webarchive/20250804190340/https://natlib.govt.nz/
# 2025-09-04 12:11:18      https://ndhadeliver.natlib.govt.nz/webarchive/20250904121118/http://natlib.govt.nz/
# 2025-09-04 12:11:24     https://ndhadeliver.natlib.govt.nz/webarchive/20250904121124/https://natlib.govt.nz/
# 2025-09-08 10:23:46      https://ndhadeliver.natlib.govt.nz/webarchive/20250908102346/http://natlib.govt.nz/
# 2025-09-08 10:23:49     https://ndhadeliver.natlib.govt.nz/webarchive/20250908102349/https://natlib.govt.nz/
#
# [1404 rows x 14 columns]

# %% [markdown]
# Note that the query results above is actually the same as timemap. But in our function, we have added a "access_url" column which contains actual URL for each webpage snapshot.

# %%
webpage = "niwa.co.nz/"
want.query_cdx_index(webpage, filter="mimetype:image/png", matchType="prefix")
# Out:
#                                                                                  urlkey  \
# timestamp
# 2008-10-09 07:19:37    nz,co,niwa)/__data/assets/image/0003/64128/vessel_background.png
# 2008-10-10 06:16:08    nz,co,niwa)/__data/assets/image/0003/64128/vessel_background.png
# 2008-10-10 11:31:13             nz,co,niwa)/__data/assets/image/0004/64624/ipy-caml.png
# 2008-10-10 12:20:56             nz,co,niwa)/__data/assets/image/0004/64624/ipy-caml.png
# 2008-10-10 18:50:23   nz,co,niwa)/__data/assets/image/0003/74469/nz_spr_probrain_en.png
# ...                                                                                 ...
# 2010-11-11 17:35:02  nz,co,niwa)/__data/assets/image/0003/97761/outrain200909_thumb.png
# 2011-06-13 14:28:50               nz,co,niwa)/__data/assets/image/0003/91632/shadow.png
# 2011-06-13 14:33:17  nz,co,niwa)/__data/assets/image/0003/83424/subnav-header-about.png
# 2011-06-29 01:47:15               nz,co,niwa)/__data/assets/image/0003/91632/shadow.png
# 2011-06-29 01:52:21  nz,co,niwa)/__data/assets/image/0003/83424/subnav-header-about.png
#
#                                                                                               url  \
# timestamp
# 2008-10-09 07:19:37    http://www.niwa.co.nz/__data/assets/image/0003/64128/vessel_background.png
# 2008-10-10 06:16:08    http://www.niwa.co.nz/__data/assets/image/0003/64128/vessel_background.png
# 2008-10-10 11:31:13                 http://niwa.co.nz/__data/assets/image/0004/64624/ipy-caml.png
# 2008-10-10 12:20:56             http://www.niwa.co.nz/__data/assets/image/0004/64624/ipy-caml.png
# 2008-10-10 18:50:23       http://niwa.co.nz/__data/assets/image/0003/74469/nz_spr_probrain_EN.png
# ...                                                                                           ...
# 2010-11-11 17:35:02  http://www.niwa.co.nz/__data/assets/image/0003/97761/outrain200909_thumb.png
# 2011-06-13 14:28:50               http://www.niwa.co.nz/__data/assets/image/0003/91632/shadow.png
# 2011-06-13 14:33:17  http://www.niwa.co.nz/__data/assets/image/0003/83424/subnav-header-about.png
# 2011-06-29 01:47:15               http://www.niwa.co.nz/__data/assets/image/0003/91632/shadow.png
# 2011-06-29 01:52:21  http://www.niwa.co.nz/__data/assets/image/0003/83424/subnav-header-about.png
#
#                           mime status                            digest  \
# timestamp
# 2008-10-09 07:19:37  image/png    200  3G3ZYUAOXKCM564FLQQ2HD6ZMP4QGW55
# 2008-10-10 06:16:08  image/png    200  3G3ZYUAOXKCM564FLQQ2HD6ZMP4QGW55
# 2008-10-10 11:31:13  image/png    200  HQVY2YENMUN7EIBBDW6OFBKEOXMOFIJC
# 2008-10-10 12:20:56  image/png    200  HQVY2YENMUN7EIBBDW6OFBKEOXMOFIJC
# 2008-10-10 18:50:23  image/png    200  2A22PN35DMRDKQ6WMAA3LO32JE4L43G7
# ...                        ...    ...                               ...
# 2010-11-11 17:35:02  image/png    200  SCIIA6RRDNJ6AS3WNQMDBHA27TAECWMH
# 2011-06-13 14:28:50  image/png    200  P2UVZ4HCIZJDCXVMJCREBIRFCLLXL625
# 2011-06-13 14:33:17  image/png    200  M2E5SQOASVVAYLI5VFA7RT5EIHUORXZF
# 2011-06-29 01:47:15  image/png    200  P2UVZ4HCIZJDCXVMJCREBIRFCLLXL625
# 2011-06-29 01:52:21  image/png    200  M2E5SQOASVVAYLI5VFA7RT5EIHUORXZF
#
#                     redirect robotflags length    offset          filename  \
# timestamp
# 2008-10-09 07:19:37        -          -      0  90648133   V1-FL617890.arc
# 2008-10-10 06:16:08        -          -      0  16823778   V1-FL619668.arc
# 2008-10-10 11:31:13        -          -      0  44575369   V1-FL619036.arc
# 2008-10-10 12:20:56        -          -      0  30778495   V1-FL619172.arc
# 2008-10-10 18:50:23        -          -      0  45258726   V1-FL618824.arc
# ...                      ...        ...    ...       ...               ...
# 2010-11-11 17:35:02        -          -      0  69134947  V1-FL2626535.arc
# 2011-06-13 14:28:50        -          -      0  84019957  V1-FL6616986.arc
# 2011-06-13 14:33:17        -          -      0  77590749  V1-FL6616985.arc
# 2011-06-29 01:47:15        -          -      0  96609486  V1-FL6264804.arc
# 2011-06-29 01:52:21        -          -      0   9411987  V1-FL6264805.arc
#
#                                                                                                                                                                        load_url  \
# timestamp
# 2008-10-09 07:19:37    https://wlgprdowapp01.natlib.govt.nz/nlnzwebarchive_PROD/ap/20081009071937id_/http://www.niwa.co.nz/__data/assets/image/0003/64128/vessel_background.png
# 2008-10-10 06:16:08    https://wlgprdowapp01.natlib.govt.nz/nlnzwebarchive_PROD/ap/20081010061608id_/http://www.niwa.co.nz/__data/assets/image/0003/64128/vessel_background.png
# 2008-10-10 11:31:13                 https://wlgprdowapp01.natlib.govt.nz/nlnzwebarchive_PROD/ap/20081010113113id_/http://niwa.co.nz/__data/assets/image/0004/64624/ipy-caml.png
# 2008-10-10 12:20:56             https://wlgprdowapp01.natlib.govt.nz/nlnzwebarchive_PROD/ap/20081010122056id_/http://www.niwa.co.nz/__data/assets/image/0004/64624/ipy-caml.png
# 2008-10-10 18:50:23       https://wlgprdowapp01.natlib.govt.nz/nlnzwebarchive_PROD/ap/20081010185023id_/http://niwa.co.nz/__data/assets/image/0003/74469/nz_spr_probrain_EN.png
# ...                                                                                                                                                                         ...
# 2010-11-11 17:35:02  https://wlgprdowapp01.natlib.govt.nz/nlnzwebarchive_PROD/ap/20101111173502id_/http://www.niwa.co.nz/__data/assets/image/0003/97761/outrain200909_thumb.png
# 2011-06-13 14:28:50               https://wlgprdowapp01.natlib.govt.nz/nlnzwebarchive_PROD/ap/20110613142850id_/http://www.niwa.co.nz/__data/assets/image/0003/91632/shadow.png
# 2011-06-13 14:33:17  https://wlgprdowapp01.natlib.govt.nz/nlnzwebarchive_PROD/ap/20110613143317id_/http://www.niwa.co.nz/__data/assets/image/0003/83424/subnav-header-about.png
# 2011-06-29 01:47:15               https://wlgprdowapp01.natlib.govt.nz/nlnzwebarchive_PROD/ap/20110629014715id_/http://www.niwa.co.nz/__data/assets/image/0003/91632/shadow.png
# 2011-06-29 01:52:21  https://wlgprdowapp01.natlib.govt.nz/nlnzwebarchive_PROD/ap/20110629015221id_/http://www.niwa.co.nz/__data/assets/image/0003/83424/subnav-header-about.png
#
#                          source source-coll  \
# timestamp
# 2008-10-09 07:19:37  webarchive  webarchive
# 2008-10-10 06:16:08  webarchive  webarchive
# 2008-10-10 11:31:13  webarchive  webarchive
# 2008-10-10 12:20:56  webarchive  webarchive
# 2008-10-10 18:50:23  webarchive  webarchive
# ...                         ...         ...
# 2010-11-11 17:35:02  webarchive  webarchive
# 2011-06-13 14:28:50  webarchive  webarchive
# 2011-06-13 14:33:17  webarchive  webarchive
# 2011-06-29 01:47:15  webarchive  webarchive
# 2011-06-29 01:52:21  webarchive  webarchive
#
#                                                                                                                                                     access_url
# timestamp
# 2008-10-09 07:19:37    https://ndhadeliver.natlib.govt.nz/webarchive/20081009071937/http://www.niwa.co.nz/__data/assets/image/0003/64128/vessel_background.png
# 2008-10-10 06:16:08    https://ndhadeliver.natlib.govt.nz/webarchive/20081010061608/http://www.niwa.co.nz/__data/assets/image/0003/64128/vessel_background.png
# 2008-10-10 11:31:13                 https://ndhadeliver.natlib.govt.nz/webarchive/20081010113113/http://niwa.co.nz/__data/assets/image/0004/64624/ipy-caml.png
# 2008-10-10 12:20:56             https://ndhadeliver.natlib.govt.nz/webarchive/20081010122056/http://www.niwa.co.nz/__data/assets/image/0004/64624/ipy-caml.png
# 2008-10-10 18:50:23       https://ndhadeliver.natlib.govt.nz/webarchive/20081010185023/http://niwa.co.nz/__data/assets/image/0003/74469/nz_spr_probrain_EN.png
# ...                                                                                                                                                        ...
# 2010-11-11 17:35:02  https://ndhadeliver.natlib.govt.nz/webarchive/20101111173502/http://www.niwa.co.nz/__data/assets/image/0003/97761/outrain200909_thumb.png
# 2011-06-13 14:28:50               https://ndhadeliver.natlib.govt.nz/webarchive/20110613142850/http://www.niwa.co.nz/__data/assets/image/0003/91632/shadow.png
# 2011-06-13 14:33:17  https://ndhadeliver.natlib.govt.nz/webarchive/20110613143317/http://www.niwa.co.nz/__data/assets/image/0003/83424/subnav-header-about.png
# 2011-06-29 01:47:15               https://ndhadeliver.natlib.govt.nz/webarchive/20110629014715/http://www.niwa.co.nz/__data/assets/image/0003/91632/shadow.png
# 2011-06-29 01:52:21  https://ndhadeliver.natlib.govt.nz/webarchive/20110629015221/http://www.niwa.co.nz/__data/assets/image/0003/83424/subnav-header-about.png
#
# [96 rows x 14 columns]

# %%
import requests


response = requests.head(
    "https://ndhadeliver.natlib.govt.nz/webarchive/http://natlib.govt.nz/",
    headers={"Accept-Datetime": "Fri, 01 Jan 2025 01:00:00 GMT", "User-Agent": "NLNZWebArchiveAccessBot/1.0 (wa-nlnz-toolkit)"},
)
response.links

# %%
df_records = want.query_cdx_index("covid19.govt.nz")#, filter="mimetype:application/pdf")
want.plot_monthly_captures(df_records)

# %%
want.query_memento("covid19.govt.nz", dt=datetime.datetime(2020, 3, 18, 5, 16, 41)).links

# %%
wa_nlnz_toolkit.get_memento_urls("covid19.govt.nz")

# %%
await wa_nlnz_toolkit.webshot("http://www.natlib.govt.nz")

# %%
g = df_records.groupby(pd.Grouper(freq="M"))
g["status"].count().plot.bar()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Example: list of archived URLs and their links
# Replace this with your own extracted link data
edges = [
    ("http://web.archive.org/web/20200101/example.com", 
     "http://web.archive.org/web/20200102/example.com/page1"),
    
    ("http://web.archive.org/web/20200101/example.com", 
     "http://web.archive.org/web/20200102/example.com/page2"),
    
    ("http://web.archive.org/web/20200102/example.com/page1", 
     "http://web.archive.org/web/20200103/example.com/page3"),

    ("http://web.archive.org/web/20200101/example.com", 
     "http://web.archive.org/web/20200102/example.com/page4"),

    ("http://web.archive.org/web/20200101/example.com", 
     "http://web.archive.org/web/20200102/example.com/page5"),

    ("http://web.archive.org/web/20200101/example.com", 
     "http://web.archive.org/web/20200102/example.com/page7"),
]

# Create a directed graph
G = nx.DiGraph()
G.add_edges_from(edges)

# Draw the graph
plt.figure(figsize=(10, 6))
pos = nx.spring_layout(G, k=0.5, iterations=50)
nx.draw(G, pos, with_labels=False, node_size=500, node_color="skyblue", arrows=True)
nx.draw_networkx_labels(G, pos, font_size=8)

plt.title("Link Graph of Web Archive URLs")
plt.show()

# %%
import networkx as nx
from pyvis.network import Network
import matplotlib.cm as cm
import matplotlib.colors as mcolors

# Step 1: Build graph with networkx
G = nx.DiGraph()
G.add_edges_from(edges)

# Step 2: Compute degrees (in+out connections)
degrees = dict(G.degree())

# Normalize degrees for colormap
norm = mcolors.Normalize(vmin=min(degrees.values()), vmax=max(degrees.values()))
cmap = cm.get_cmap("plasma")  # you can try "plasma", "coolwarm", etc.

# Step 3: Create Pyvis network
net = Network(height="1200px", width="100%", directed=True)

for node, deg in degrees.items():
    # Convert degree to RGBA then to HEX
    rgba = cmap(norm(deg))
    color = mcolors.to_hex(rgba)
    
    net.add_node(node, 
                 label=node.split("/")[-1],  # show shorter label
                 title=f"{node}<br>Degree: {deg}",
                 color=color)

# Step 4: Add edges
for u, v in edges:
    net.add_edge(u, v)

# Step 5: Save and open interactive graph
net.save_graph("archive_linkgraph_colored.html")
